# %% [markdown]
# <a href="https://colab.research.google.com/github/ab17254/dissertation/blob/main/data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tweepy is a python library to access Twitter API.
import tweepy
import csv
import pandas as pd
import os

# %%
#Provide your own credentials here.
consumer_key = '9CtULzOKwtotSBbgmqqF5ZSE1'
consumer_secret = 'SFDNiyOXgkPjQvETZXnQOWemCqrssBsZVe3ACYHF2AkA0giPNm'
access_token = '711310452815503360-SfHfZuJSf5vOLBQQOdZGN7GNxaMTNS0'
access_token_secret = 'ybUU3Sq5lWNMpZAyRgJZIPRW960PtwT2jFrfOAQIKEXp1'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
users = ['Conservatives',
'theresa_may',
'DamianGreen',
'PhilipHammondUK',
'AmberRuddUK',
'DavidDavisMP',
'BorisJohnson',
'Jeremy_Hunt',
'DLidington',
'JustineGreening',
'LiamFox',
'GregClarkMP',
'michaelgove',
'sajidjavid',
'pritipatel',
'andrealeadsom',
'GavinWilliamson',
'DominicRaab',
'MattHancock',
'UKLabour',
'jeremycorbyn',
'tom_watson',
'angelaeagle',
'EmilyThornberry',
'johnmcdonnellMP',
'hilarybennmp',
'HackneyAbbott',
'labourlewis',
'RLong_Bailey',
'JonAshworth',
'AngelaRayner',
'Keir_Starmer',
'RichardBurgon',
'DawnButlerBrent',
'lisanandy',
'DavidLammy',
'LibDems',
'timfarron',
'vincecable',
'joswinson',
'EdwardJDavey',
'theSNP',
'NicolaSturgeon',
'Ianblackford_MP',
'AngusRobertson',
'UKIP',
'paulnuttalukips',
'Nigel_Farage',
'TheGreenParty',
'natalieben',
'BBCNews',
'bbclaurak',
'skynews',
'LBC',
'YouGov',
'guardian']

# %%
# install Anaconda3
# !wget -qO ac.sh https://repo.anaconda.com/archive/Anaconda3-2020.07-Linux-x86_64.sh 
# !bash ./ac.sh -b

# a fake google.colab library
# !ln -s /usr/local/lib/python3.7/dist-packages/google \
       /root/anaconda3/lib/python3.8/site-packages/google

# start jupyterlab, which now has Python3 = 3.8
# !nohup /root/anaconda3/bin/jupyter-lab --ip=0.0.0.0&

# access through ngrok, click the link
# !pip install pyngrok -q
from pyngrok import ngrok
print(ngrok.connect(8888))

os.environ['PATH'] = '/root/anaconda3/bin:' + os.environ['PATH']
# Out:
# PREFIX=/root/anaconda3
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /root/anaconda3
#
#   added / updated specs:
#     - _ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#     - _libgcc_mutex==0.1=main
#     - alabaster==0.7.12=py_0
#     - anaconda-client==1.7.2=py38_0
#     - anaconda-navigator==1.9.12=py38_0
#     - anaconda-project==0.8.4=py_0
#     - anaconda==2020.07=py38_0
#     - argh==0.26.2=py38_0
#     - asn1crypto==1.3.0=py38_0
#     - astroid==2.4.2=py38_0
#     - astropy==4.0.1.post1=py38h7b6447c_1
#     - atomicwrites==1.4.0=py_0
#     - attrs==19.3.0=py_0
#     - autopep8==1.5.3=py_0
#     - babel==2.8.0=py_0
#     - backcall==0.2.0=py_0
#     - backports.functools_lru_cache==1.6.1=py_0
#     - backports.shutil_get_terminal_size==1.0.0=py38_2
#     - backports.tempfile==1.0=py_1
#     - backports.weakref==1.0.post1=py_1
#     - backports==1.0=py_2
#     - beautifulsoup4==4.9.1=py38_0
#     - bitarray==1.4.0=py38h7b6447c_0
# ...

# %%
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-v1uur3xh
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-v1uur3xh
# ...
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev104+g97c8cae-py3-none-any.whl size=50542 sha256=15bd7dd135aaaed06bf84d85c9e77ccd6597461c9ab485801310b3f49590458c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gp6qj8rf/wheels/92/42/87/33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape
# ...

# %%
# !git clone https://github.com/JustAnotherArchivist/snscrape.git
# %cd /content/snscrape
# !git pull origin master
# !python setup.py install
# Out:
# fatal: destination path 'snscrape' already exists and is not an empty directory.
# /content/snscrape
# From https://github.com/JustAnotherArchivist/snscrape
#  * branch            master     -> FETCH_HEAD
# Already up to date.
# running install
# running bdist_egg
# running egg_info
# writing snscrape.egg-info/PKG-INFO
# writing dependency_links to snscrape.egg-info/dependency_links.txt
# writing entry points to snscrape.egg-info/entry_points.txt
# writing requirements to snscrape.egg-info/requires.txt
# writing top-level names to snscrape.egg-info/top_level.txt
# writing manifest file 'snscrape.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/snscrape
# copying build/lib/snscrape/base.py -> build/bdist.linux-x86_64/egg/snscrape
# copying build/lib/snscrape/_cli.py -> build/bdist.linux-x86_64/egg/snscrape
# ...

# %%
!--python-version 3.8
# Out:
# /bin/bash: --: invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option

# %%
import snscrape.modules.twitter as sntwitter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-da0f0c3452db> in <module>()
# ----> 1 import snscrape.modules.twitter as sntwitter
#
# /content/snscrape/snscrape/modules/__init__.py in <module>()
#       1 import importlib
#       2 import os
# ----> 3 import snscrape.base
#       4
#       5
#
# /content/snscrape/snscrape/base.py in <module>()
#     123
#     124
# --> 125 class Scraper:
#     126         '''An abstract base class for a scraper.'''
#     127
#
# /content/snscrape/snscrape/base.py in Scraper()
#     143                 return None
#     144
# --> 145         @functools.cached_property
#     146         def entity(self):
#     147                 return self._get_entity()
#
# AttributeError: module 'functools' has no attribute 'cached_property'

# %%
sntwitter
# Out:
# <module 'snscrape' from '/content/snscrape/snscrape/__init__.py'>

# %%
csvFile = open('output.csv', 'a') #creates a file in which you want to store the data.
csvWriter = csv.writer(csvFile)

# %%
# the number of tweets you require
for user in users:
  search = ' from:'+'"{}"'.format(user)
  for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Covid' + search).get_items()) :
    csvWriter.writerow([tweet.date, tweet.content.encode('utf-8'), tweet.username, tweet.id, tweet.user]) #If you need more information, just provide the attributes
    print(tweet.date)

# %%
df = pd.read_csv('/content/output.csv', names=['Date', 'Content', 'User', 'ID'] )

# %%
df

# %%
# API: snscrape.modules.twitter.TwitterUserScraper('screenname').entity
